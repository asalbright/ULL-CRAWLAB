# %% [markdown]
# ### Includes and Hyperameters

# %%
import sys
import torch  
import gym
import numpy as np  
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.autograd import Variable
import matplotlib.pyplot as plt
import pandas as pd

# hyperparameters
hidden_size = 256
learning_rate = 3e-4

# Constants
GAMMA = 0.99
num_steps = 300
max_episodes = 3000

# %% [markdown]
# ### Implement the Actor Critic Network

# %%
class ActorCritic(nn.Module):
    def __init__(self, num_inputs, num_actions, hidden_size, learning_rate=3e-4):
        super(ActorCritic, self).__init__()

        self.num_actions = num_actions
        self.critic_linear1 = nn.Linear(num_inputs, hidden_size)
        self.critic_linear2 = nn.Linear(hidden_size, 1)

        self.actor_linear1 = nn.Linear(num_inputs, hidden_size)
        self.actor_linear2 = nn.Linear(hidden_size, num_actions)
    
    def forward(self, state):
        state = Variable(torch.from_numpy(state).float().unsqueeze(0))
        value = F.relu(self.critic_linear1(state))
        value = self.critic_linear2(value)
        
        policy_dist = F.relu(self.actor_linear1(state))
        policy_dist = F.softmax(self.actor_linear2(policy_dist), dim=1)

        return value, policy_dist

# %% [markdown]
# ### The Main loop and Update loop

# %%
def a2c(env):
    num_inputs = env.observation_space.shape[0]
    num_outputs = env.action_space.n
    
    actor_critic = ActorCritic(num_inputs, num_outputs, hidden_size)
    ac_optimizer = optim.Adam(actor_critic.parameters(), lr=learning_rate)

    all_lengths = []
    average_lengths = []
    all_rewards = []
    entropy_term = 0

    for episode in range(max_episodes):
        log_probs = []
        values = []
        rewards = []

        state = env.reset()
        for steps in range(num_steps):
            value, policy_dist = actor_critic.forward(state)
            value = value.detach().numpy()[0,0]
            dist = policy_dist.detach().numpy() 

            action = np.random.choice(num_outputs, p=np.squeeze(dist))
            log_prob = torch.log(policy_dist.squeeze(0)[action])
            entropy = -np.sum(np.mean(dist) * np.log(dist))
            new_state, reward, done, _ = env.step(action)

            rewards.append(reward)
            values.append(value)
            log_probs.append(log_prob)
            entropy_term += entropy
            state = new_state
            
            if done or steps == num_steps-1:
                Qval, _ = actor_critic.forward(new_state)
                Qval = Qval.detach().numpy()[0,0]
                all_rewards.append(np.sum(rewards))
                all_lengths.append(steps)
                average_lengths.append(np.mean(all_lengths[-10:]))
                if episode % 10 == 0:                    
                    sys.stdout.write("episode: {}, reward: {}, total length: {}, average length: {} \n".format(episode, np.sum(rewards), steps, average_lengths[-1]))
                break
        
        # compute Q values
        Qvals = np.zeros_like(values)
        for t in reversed(range(len(rewards))):
            Qval = rewards[t] + GAMMA * Qval
            Qvals[t] = Qval
  
        #update actor critic
        values = torch.FloatTensor(values)
        Qvals = torch.FloatTensor(Qvals)
        log_probs = torch.stack(log_probs)
        
        advantage = Qvals - values
        actor_loss = (-log_probs * advantage).mean()
        critic_loss = 0.5 * advantage.pow(2).mean()
        ac_loss = actor_loss + critic_loss + 0.001 * entropy_term

        ac_optimizer.zero_grad()
        ac_loss.backward()
        ac_optimizer.step()

        
    
    # Plot results
    smoothed_rewards = pd.Series.rolling(pd.Series(all_rewards), 10).mean()
    smoothed_rewards = [elem for elem in smoothed_rewards]
    plt.plot(all_rewards)
    plt.plot(smoothend_rewards)
    plt.plot()
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    plt.show()

    plt.plot(all_lengths)
    plt.plot(average_lengths)
    plt.xlabel('Episode')
    plt.ylabel('Episode length')
    plt.show()

# %% [markdown]
# ### Running the Code

# %%
if __name__ == "__main__":
    env = gym.make("CartPole-v0")
    a2c(env)
# Out:
# episode: 0, reward: 10.0, total length: 9, average length: 9.0
# episode: 10, reward: 44.0, total length: 43, average length: 18.1
# episode: 20, reward: 21.0, total length: 20, average length: 18.0
# episode: 30, reward: 12.0, total length: 11, average length: 19.6
# episode: 40, reward: 14.0, total length: 13, average length: 16.9
# episode: 50, reward: 11.0, total length: 10, average length: 18.5
# episode: 60, reward: 16.0, total length: 15, average length: 16.5
# episode: 70, reward: 26.0, total length: 25, average length: 16.4
# episode: 80, reward: 14.0, total length: 13, average length: 11.3
# episode: 90, reward: 11.0, total length: 10, average length: 14.4
# episode: 100, reward: 13.0, total length: 12, average length: 15.3
# episode: 110, reward: 19.0, total length: 18, average length: 13.1
# episode: 120, reward: 21.0, total length: 20, average length: 25.3
# episode: 130, reward: 10.0, total length: 9, average length: 13.0
# episode: 140, reward: 15.0, total length: 14, average length: 17.5
# episode: 150, reward: 27.0, total length: 26, average length: 19.1
# episode: 160, reward: 13.0, total length: 12, average length: 16.8
# episode: 170, reward: 17.0, total length: 16, average length: 20.0
# episode: 180, reward: 14.0, total length: 13, average length: 15.9
# episode: 190, reward: 12.0, total length: 11, average length: 21.9
# episode: 200, reward: 35.0, total length: 34, average length: 26.5
# episode: 210, reward: 32.0, total length: 31, average length: 19.8
# episode: 220, reward: 63.0, total length: 62, average length: 31.2
# episode: 230, reward: 25.0, total length: 24, average length: 27.1
# episode: 240, reward: 20.0, total length: 19, average length: 27.2
# episode: 250, reward: 28.0, total length: 27, average length: 18.5
# episode: 260, reward: 35.0, total length: 34, average length: 24.1
# episode: 270, reward: 20.0, total length: 19, average length: 28.7
# episode: 280, reward: 17.0, total length: 16, average length: 27.8
# episode: 290, reward: 14.0, total length: 13, average length: 27.8
# episode: 300, reward: 19.0, total length: 18, average length: 23.8
# episode: 310, reward: 48.0, total length: 47, average length: 28.3
# episode: 320, reward: 31.0, total length: 30, average length: 40.8
# episode: 330, reward: 30.0, total length: 29, average length: 37.3
# episode: 340, reward: 53.0, total length: 52, average length: 34.4
# episode: 350, reward: 41.0, total length: 40, average length: 34.3
# episode: 360, reward: 23.0, total length: 22, average length: 28.4
# episode: 370, reward: 90.0, total length: 89, average length: 52.3
# episode: 380, reward: 18.0, total length: 17, average length: 29.6
# episode: 390, reward: 21.0, total length: 20, average length: 39.3
# episode: 400, reward: 39.0, total length: 38, average length: 29.5
# episode: 410, reward: 21.0, total length: 20, average length: 31.0
# episode: 420, reward: 21.0, total length: 20, average length: 35.8
# episode: 430, reward: 39.0, total length: 38, average length: 34.1
# episode: 440, reward: 16.0, total length: 15, average length: 32.5
# episode: 450, reward: 19.0, total length: 18, average length: 45.4
# episode: 460, reward: 47.0, total length: 46, average length: 43.9
# episode: 470, reward: 76.0, total length: 75, average length: 53.7
# episode: 480, reward: 154.0, total length: 153, average length: 54.4
# episode: 490, reward: 49.0, total length: 48, average length: 58.7
# episode: 500, reward: 39.0, total length: 38, average length: 51.0
# episode: 510, reward: 56.0, total length: 55, average length: 46.4
# episode: 520, reward: 32.0, total length: 31, average length: 56.4
# episode: 530, reward: 25.0, total length: 24, average length: 39.9
# episode: 540, reward: 52.0, total length: 51, average length: 57.8
# episode: 550, reward: 27.0, total length: 26, average length: 36.7
# episode: 560, reward: 69.0, total length: 68, average length: 67.3
# episode: 570, reward: 12.0, total length: 11, average length: 48.5
# episode: 580, reward: 47.0, total length: 46, average length: 63.3
# episode: 590, reward: 74.0, total length: 73, average length: 49.2
# episode: 600, reward: 62.0, total length: 61, average length: 62.0
# episode: 610, reward: 36.0, total length: 35, average length: 47.3
# episode: 620, reward: 37.0, total length: 36, average length: 54.3
# episode: 630, reward: 130.0, total length: 129, average length: 59.3
# episode: 640, reward: 23.0, total length: 22, average length: 41.4
# episode: 650, reward: 48.0, total length: 47, average length: 69.1
# episode: 660, reward: 77.0, total length: 76, average length: 56.6
# episode: 670, reward: 37.0, total length: 36, average length: 86.1
# episode: 680, reward: 58.0, total length: 57, average length: 74.5
# episode: 690, reward: 128.0, total length: 127, average length: 83.3
# episode: 700, reward: 76.0, total length: 75, average length: 64.2
# episode: 710, reward: 68.0, total length: 67, average length: 61.6
# episode: 720, reward: 30.0, total length: 29, average length: 63.7
# episode: 730, reward: 47.0, total length: 46, average length: 49.3
# episode: 740, reward: 54.0, total length: 53, average length: 73.4
# episode: 750, reward: 90.0, total length: 89, average length: 53.9
# episode: 760, reward: 68.0, total length: 67, average length: 87.8
# episode: 770, reward: 67.0, total length: 66, average length: 78.2
# episode: 780, reward: 26.0, total length: 25, average length: 67.1
# episode: 790, reward: 200.0, total length: 199, average length: 92.1
# episode: 800, reward: 76.0, total length: 75, average length: 107.3
# episode: 810, reward: 200.0, total length: 199, average length: 112.1
# episode: 820, reward: 137.0, total length: 136, average length: 80.4
# episode: 830, reward: 158.0, total length: 157, average length: 106.6
# episode: 840, reward: 94.0, total length: 93, average length: 116.0
# episode: 850, reward: 73.0, total length: 72, average length: 133.4
# episode: 860, reward: 109.0, total length: 108, average length: 120.2
# episode: 870, reward: 62.0, total length: 61, average length: 127.1
# episode: 880, reward: 72.0, total length: 71, average length: 136.7
# episode: 890, reward: 83.0, total length: 82, average length: 115.5
# episode: 900, reward: 159.0, total length: 158, average length: 150.5
# episode: 910, reward: 166.0, total length: 165, average length: 126.7
# episode: 920, reward: 112.0, total length: 111, average length: 111.0
# episode: 930, reward: 123.0, total length: 122, average length: 117.6
# episode: 940, reward: 40.0, total length: 39, average length: 104.1
# episode: 950, reward: 127.0, total length: 126, average length: 153.0
# episode: 960, reward: 43.0, total length: 42, average length: 125.4
# episode: 970, reward: 200.0, total length: 199, average length: 141.3
# episode: 980, reward: 61.0, total length: 60, average length: 141.4
# episode: 990, reward: 115.0, total length: 114, average length: 154.8
# episode: 1000, reward: 175.0, total length: 174, average length: 136.0
# episode: 1010, reward: 64.0, total length: 63, average length: 122.2
# episode: 1020, reward: 175.0, total length: 174, average length: 156.7
# episode: 1030, reward: 123.0, total length: 122, average length: 158.1
# episode: 1040, reward: 151.0, total length: 150, average length: 130.6
# episode: 1050, reward: 107.0, total length: 106, average length: 106.3
# episode: 1060, reward: 141.0, total length: 140, average length: 115.8
# episode: 1070, reward: 181.0, total length: 180, average length: 124.3
# episode: 1080, reward: 133.0, total length: 132, average length: 89.8
# episode: 1090, reward: 120.0, total length: 119, average length: 131.7
# episode: 1100, reward: 43.0, total length: 42, average length: 149.4
# episode: 1110, reward: 200.0, total length: 199, average length: 167.8
# episode: 1120, reward: 169.0, total length: 168, average length: 156.7
# episode: 1130, reward: 133.0, total length: 132, average length: 166.5
# episode: 1140, reward: 63.0, total length: 62, average length: 122.8
# episode: 1150, reward: 186.0, total length: 185, average length: 143.4
# episode: 1160, reward: 66.0, total length: 65, average length: 144.3
# episode: 1170, reward: 200.0, total length: 199, average length: 174.4
# episode: 1180, reward: 198.0, total length: 197, average length: 156.6
# episode: 1190, reward: 164.0, total length: 163, average length: 149.3
# episode: 1200, reward: 163.0, total length: 162, average length: 128.3
# episode: 1210, reward: 200.0, total length: 199, average length: 168.7
# episode: 1220, reward: 200.0, total length: 199, average length: 166.6
# episode: 1230, reward: 200.0, total length: 199, average length: 162.9
# episode: 1240, reward: 200.0, total length: 199, average length: 169.5
# episode: 1250, reward: 200.0, total length: 199, average length: 167.1
# episode: 1260, reward: 127.0, total length: 126, average length: 159.0
# episode: 1270, reward: 128.0, total length: 127, average length: 88.0
# episode: 1280, reward: 45.0, total length: 44, average length: 103.3
# episode: 1290, reward: 137.0, total length: 136, average length: 132.2
# episode: 1300, reward: 157.0, total length: 156, average length: 145.1
# episode: 1310, reward: 200.0, total length: 199, average length: 169.1
# episode: 1320, reward: 200.0, total length: 199, average length: 165.3
# episode: 1330, reward: 200.0, total length: 199, average length: 156.1
# episode: 1340, reward: 189.0, total length: 188, average length: 171.2
# episode: 1350, reward: 200.0, total length: 199, average length: 166.6
# episode: 1360, reward: 200.0, total length: 199, average length: 189.5
# episode: 1370, reward: 200.0, total length: 199, average length: 172.6
# episode: 1380, reward: 178.0, total length: 177, average length: 163.3
# episode: 1390, reward: 200.0, total length: 199, average length: 167.0
# episode: 1400, reward: 157.0, total length: 156, average length: 139.6
# episode: 1410, reward: 200.0, total length: 199, average length: 183.5
# episode: 1420, reward: 172.0, total length: 171, average length: 153.0
# episode: 1430, reward: 117.0, total length: 116, average length: 180.3
# episode: 1440, reward: 49.0, total length: 48, average length: 167.1
# episode: 1450, reward: 152.0, total length: 151, average length: 183.1
# episode: 1460, reward: 135.0, total length: 134, average length: 176.3
# episode: 1470, reward: 200.0, total length: 199, average length: 186.7
# episode: 1480, reward: 78.0, total length: 77, average length: 158.6
# episode: 1490, reward: 197.0, total length: 196, average length: 180.5
# episode: 1500, reward: 121.0, total length: 120, average length: 171.3
# episode: 1510, reward: 119.0, total length: 118, average length: 181.2
# episode: 1520, reward: 136.0, total length: 135, average length: 159.4
# episode: 1530, reward: 123.0, total length: 122, average length: 164.5
# episode: 1540, reward: 200.0, total length: 199, average length: 156.7
# episode: 1550, reward: 59.0, total length: 58, average length: 150.6
# episode: 1560, reward: 175.0, total length: 174, average length: 155.4
# episode: 1570, reward: 152.0, total length: 151, average length: 156.2
# episode: 1580, reward: 200.0, total length: 199, average length: 178.0
# episode: 1590, reward: 138.0, total length: 137, average length: 156.0
# episode: 1600, reward: 200.0, total length: 199, average length: 166.8
# episode: 1610, reward: 183.0, total length: 182, average length: 172.9
# episode: 1620, reward: 59.0, total length: 58, average length: 151.0
# episode: 1630, reward: 192.0, total length: 191, average length: 150.5
# episode: 1640, reward: 200.0, total length: 199, average length: 142.3
# episode: 1650, reward: 200.0, total length: 199, average length: 168.4
# episode: 1660, reward: 147.0, total length: 146, average length: 168.4
# episode: 1670, reward: 145.0, total length: 144, average length: 143.4
# episode: 1680, reward: 114.0, total length: 113, average length: 135.7
# episode: 1690, reward: 100.0, total length: 99, average length: 143.2
# episode: 1700, reward: 147.0, total length: 146, average length: 131.4
# episode: 1710, reward: 57.0, total length: 56, average length: 101.3
# episode: 1720, reward: 119.0, total length: 118, average length: 120.2
# episode: 1730, reward: 135.0, total length: 134, average length: 119.3
# episode: 1740, reward: 95.0, total length: 94, average length: 109.8
# episode: 1750, reward: 125.0, total length: 124, average length: 122.4
# episode: 1760, reward: 156.0, total length: 155, average length: 103.7
# episode: 1770, reward: 145.0, total length: 144, average length: 123.9
# episode: 1780, reward: 141.0, total length: 140, average length: 130.8
# episode: 1790, reward: 161.0, total length: 160, average length: 157.5
# episode: 1800, reward: 195.0, total length: 194, average length: 162.5
# episode: 1810, reward: 128.0, total length: 127, average length: 162.2
# episode: 1820, reward: 149.0, total length: 148, average length: 157.5
# episode: 1830, reward: 180.0, total length: 179, average length: 162.6
# episode: 1840, reward: 200.0, total length: 199, average length: 155.1
# episode: 1850, reward: 149.0, total length: 148, average length: 121.2
# episode: 1860, reward: 171.0, total length: 170, average length: 163.2
# episode: 1870, reward: 146.0, total length: 145, average length: 134.3
# episode: 1880, reward: 172.0, total length: 171, average length: 125.1
# episode: 1890, reward: 109.0, total length: 108, average length: 119.2
# episode: 1900, reward: 41.0, total length: 40, average length: 130.0
# episode: 1910, reward: 130.0, total length: 129, average length: 139.9
# episode: 1920, reward: 104.0, total length: 103, average length: 149.4
# episode: 1930, reward: 133.0, total length: 132, average length: 150.4
# episode: 1940, reward: 200.0, total length: 199, average length: 140.7
# episode: 1950, reward: 106.0, total length: 105, average length: 136.9
# episode: 1960, reward: 181.0, total length: 180, average length: 146.7
# episode: 1970, reward: 158.0, total length: 157, average length: 141.8
# episode: 1980, reward: 164.0, total length: 163, average length: 151.5
# episode: 1990, reward: 178.0, total length: 177, average length: 175.7
# episode: 2000, reward: 147.0, total length: 146, average length: 155.3
# episode: 2010, reward: 176.0, total length: 175, average length: 162.6
# episode: 2020, reward: 200.0, total length: 199, average length: 169.9
# episode: 2030, reward: 196.0, total length: 195, average length: 175.5
# episode: 2040, reward: 200.0, total length: 199, average length: 196.5
# episode: 2050, reward: 161.0, total length: 160, average length: 187.5
# episode: 2060, reward: 200.0, total length: 199, average length: 193.4
# episode: 2070, reward: 200.0, total length: 199, average length: 199.0
# episode: 2080, reward: 200.0, total length: 199, average length: 174.5
# episode: 2090, reward: 200.0, total length: 199, average length: 185.8
# episode: 2100, reward: 200.0, total length: 199, average length: 196.6
# episode: 2110, reward: 200.0, total length: 199, average length: 197.3
# episode: 2120, reward: 200.0, total length: 199, average length: 196.0
# episode: 2130, reward: 200.0, total length: 199, average length: 184.0
# episode: 2140, reward: 200.0, total length: 199, average length: 194.3
# episode: 2150, reward: 200.0, total length: 199, average length: 199.0
# episode: 2160, reward: 106.0, total length: 105, average length: 185.7
# episode: 2170, reward: 200.0, total length: 199, average length: 186.7
# episode: 2180, reward: 200.0, total length: 199, average length: 199.0
# episode: 2190, reward: 179.0, total length: 178, average length: 188.0
# episode: 2200, reward: 200.0, total length: 199, average length: 197.8
# episode: 2210, reward: 200.0, total length: 199, average length: 198.7
# episode: 2220, reward: 200.0, total length: 199, average length: 198.7
# episode: 2230, reward: 200.0, total length: 199, average length: 186.5
# episode: 2240, reward: 200.0, total length: 199, average length: 199.0
# episode: 2250, reward: 200.0, total length: 199, average length: 185.8
# episode: 2260, reward: 200.0, total length: 199, average length: 195.2
# episode: 2270, reward: 200.0, total length: 199, average length: 192.3
# episode: 2280, reward: 200.0, total length: 199, average length: 189.8
# episode: 2290, reward: 200.0, total length: 199, average length: 182.3
# episode: 2300, reward: 200.0, total length: 199, average length: 176.4
# episode: 2310, reward: 200.0, total length: 199, average length: 190.3
# episode: 2320, reward: 160.0, total length: 159, average length: 177.0
# episode: 2330, reward: 200.0, total length: 199, average length: 192.4
# episode: 2340, reward: 121.0, total length: 120, average length: 176.1
# episode: 2350, reward: 200.0, total length: 199, average length: 174.6
# episode: 2360, reward: 200.0, total length: 199, average length: 184.4
# episode: 2370, reward: 200.0, total length: 199, average length: 195.6
# episode: 2380, reward: 200.0, total length: 199, average length: 181.1
# episode: 2390, reward: 185.0, total length: 184, average length: 181.3
# episode: 2400, reward: 190.0, total length: 189, average length: 186.8
# episode: 2410, reward: 153.0, total length: 152, average length: 181.0
# episode: 2420, reward: 200.0, total length: 199, average length: 177.6
# episode: 2430, reward: 141.0, total length: 140, average length: 152.8
# episode: 2440, reward: 119.0, total length: 118, average length: 151.3
# episode: 2450, reward: 144.0, total length: 143, average length: 146.0
# episode: 2460, reward: 140.0, total length: 139, average length: 156.4
# episode: 2470, reward: 159.0, total length: 158, average length: 133.1
# episode: 2480, reward: 130.0, total length: 129, average length: 127.7
# episode: 2490, reward: 128.0, total length: 127, average length: 130.9
# episode: 2500, reward: 151.0, total length: 150, average length: 138.0
# episode: 2510, reward: 142.0, total length: 141, average length: 144.8
# episode: 2520, reward: 150.0, total length: 149, average length: 155.8
# episode: 2530, reward: 160.0, total length: 159, average length: 153.0
# episode: 2540, reward: 140.0, total length: 139, average length: 150.2
# episode: 2550, reward: 112.0, total length: 111, average length: 149.2
# episode: 2560, reward: 138.0, total length: 137, average length: 117.0
# episode: 2570, reward: 145.0, total length: 144, average length: 139.5
# episode: 2580, reward: 137.0, total length: 136, average length: 139.5
# episode: 2590, reward: 154.0, total length: 153, average length: 143.2
# episode: 2600, reward: 111.0, total length: 110, average length: 139.2
# episode: 2610, reward: 174.0, total length: 173, average length: 182.9
# episode: 2620, reward: 157.0, total length: 156, average length: 178.3
# episode: 2630, reward: 143.0, total length: 142, average length: 172.0
# episode: 2640, reward: 200.0, total length: 199, average length: 162.8
# episode: 2650, reward: 181.0, total length: 180, average length: 176.7
# episode: 2660, reward: 200.0, total length: 199, average length: 185.7
# episode: 2670, reward: 200.0, total length: 199, average length: 195.5
# episode: 2680, reward: 136.0, total length: 135, average length: 175.4
# episode: 2690, reward: 200.0, total length: 199, average length: 188.6
# episode: 2700, reward: 197.0, total length: 196, average length: 183.9
# episode: 2710, reward: 200.0, total length: 199, average length: 178.2
# episode: 2720, reward: 200.0, total length: 199, average length: 192.9
# episode: 2730, reward: 177.0, total length: 176, average length: 175.8
# episode: 2740, reward: 200.0, total length: 199, average length: 197.5
# episode: 2750, reward: 194.0, total length: 193, average length: 176.1
# episode: 2760, reward: 40.0, total length: 39, average length: 169.3
# episode: 2770, reward: 147.0, total length: 146, average length: 173.2
# episode: 2780, reward: 178.0, total length: 177, average length: 114.3
# episode: 2790, reward: 44.0, total length: 43, average length: 152.8
# episode: 2800, reward: 152.0, total length: 151, average length: 167.5
# episode: 2810, reward: 178.0, total length: 177, average length: 145.2
# episode: 2820, reward: 187.0, total length: 186, average length: 154.1
# episode: 2830, reward: 155.0, total length: 154, average length: 154.9
# episode: 2840, reward: 190.0, total length: 189, average length: 174.2
# episode: 2850, reward: 121.0, total length: 120, average length: 145.7
# episode: 2860, reward: 200.0, total length: 199, average length: 173.7
# episode: 2870, reward: 136.0, total length: 135, average length: 173.5
# episode: 2880, reward: 178.0, total length: 177, average length: 170.4
# episode: 2890, reward: 172.0, total length: 171, average length: 177.9
# episode: 2900, reward: 151.0, total length: 150, average length: 174.2
# episode: 2910, reward: 200.0, total length: 199, average length: 190.8
# episode: 2920, reward: 200.0, total length: 199, average length: 183.5
# episode: 2930, reward: 200.0, total length: 199, average length: 165.7
# episode: 2940, reward: 200.0, total length: 199, average length: 188.2
# episode: 2950, reward: 200.0, total length: 199, average length: 181.1
# episode: 2960, reward: 200.0, total length: 199, average length: 174.0
# episode: 2970, reward: 200.0, total length: 199, average length: 185.3
# episode: 2980, reward: 119.0, total length: 118, average length: 179.5
# episode: 2990, reward: 200.0, total length: 199, average length: 156.9
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c64e7b38f26e> in <module>()
#       1 if __name__ == "__main__":
#       2     env = gym.make("CartPole-v0")
# ----> 3     a2c(env)
#
# <ipython-input-8-f71faa2cf810> in a2c(env)
#      69     smoothed_rewards = [elem for elem in smoothed_rewards]
#      70     plt.plot(all_rewards)
# ---> 71     plt.plot(smoothend_rewards)
#      72     plt.plot()
#      73     plt.xlabel('Episode')
#
# NameError: name 'smoothend_rewards' is not defined
